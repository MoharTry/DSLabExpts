# %% [markdown]
# ## Abhishek Dubey
# ## 211060031

# %%
import pandas as pd

# Read the CSV file into a DataFrame
spotify_songs = pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-01-21/spotify_songs.csv')

# Print the DataFrame to view its contents
print(spotify_songs)
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %%
spotify_songs.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# ...

# %%
spotify_songs.tail()
# Out:
#                      track_id                            track_name  \
# 32828  7bxnKAamR3snQ1VGLuVfC1  City Of Lights - Official Radio Edit
# 32829  5Aevni09Em4575077nkWHz   Closer - Sultan & Ned Shepard Remix
# 32830  7ImMqPP3Q1yfUHvsdn7wEo          Sweet Surrender - Radio Edit
# 32831  2m69mhnfQ1Oq6lGtXuYhgX        Only For You - Maor Levi Remix
# 32832  29zWqhca3zt5NsckZqDf6c                Typhoon - Original Mix
#
#          track_artist  track_popularity          track_album_id  \
# 32828    Lush & Simon                42  2azRoBBWEEEYhqV6sb7JrT
# 32829  Tegan and Sara                20  6kD6KLxj7s8eCE3ABvAyf5
# 32830     Starkillers                14  0ltWNSY9JgxoIZO4VzuCa6
# 32831          Mat Zo                15  1fGrOkHnHJcStl14zNx8Jy
# 32832    Julian Calor                27  0X3mUOm6MhxR7PzxG95rAo
#
#                    track_album_name track_album_release_date    playlist_name  \
# 32828    City Of Lights (Vocal Mix)               2014-04-28  ♥ EDM LOVE 2020
# ...

# %%
spotify_songs.columns
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')

# %%
spotify_songs.describe
# Out:
# <bound method NDFrame.describe of                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %%
spotify_songs.dtypes
# Out:
# track_id                     object
# track_name                   object
# track_artist                 object
# track_popularity              int64
# track_album_id               object
# track_album_name             object
# track_album_release_date     object
# playlist_name                object
# playlist_id                  object
# playlist_genre               object
# playlist_subgenre            object
# danceability                float64
# energy                      float64
# key                           int64
# loudness                    float64
# mode                          int64
# speechiness                 float64
# acousticness                float64
# instrumentalness            float64
# liveness                    float64
# valence                     float64
# tempo                       float64
# duration_ms                   int64
# dtype: object

# %%
spotify_songs.shape
# Out:
# (32833, 23)

# %%
spotify_songs.size
# Out:
# 755159

# %%
import pandas as pd
pd.notnull(spotify_songs)
# Out:
#        track_id  track_name  track_artist  track_popularity  track_album_id  \
# 0          True        True          True              True            True
# 1          True        True          True              True            True
# 2          True        True          True              True            True
# 3          True        True          True              True            True
# 4          True        True          True              True            True
# ...         ...         ...           ...               ...             ...
# 32828      True        True          True              True            True
# 32829      True        True          True              True            True
# 32830      True        True          True              True            True
# 32831      True        True          True              True            True
# 32832      True        True          True              True            True
#
# ...

# %%
pd.isnull(spotify_songs)
# Out:
#        track_id  track_name  track_artist  track_popularity  track_album_id  \
# 0         False       False         False             False           False
# 1         False       False         False             False           False
# 2         False       False         False             False           False
# 3         False       False         False             False           False
# 4         False       False         False             False           False
# ...         ...         ...           ...               ...             ...
# 32828     False       False         False             False           False
# 32829     False       False         False             False           False
# 32830     False       False         False             False           False
# 32831     False       False         False             False           False
# 32832     False       False         False             False           False
#
# ...

# %%
spotify_songs.groupby(['playlist_name','track_popularity']).sum()
# Out:
#                                                                         track_id  \
# playlist_name     track_popularity
# "Permanent Wave"  0                 07K9jPEoVsqoEopODxiAUs2fzRBJ6xbrHGyRCBR2fE9n
#                   9                                       6KgC7EDUXYwEa4qHLZMSuO
#                   18                                      5TM2eqdzfWPHklI7YnBmsD
#                   23                                      0GNlKuzh7ZJTJ1iigkQEVp
#                   24                                      2YIeE3ClUqkonhOViNHbGq
# ...                                                                          ...
# 🤩🤪Post Teen Pop🤪🤩 76                                      6epn3r7S14KUqlReYr77hA
#                   79                                      1Je1IMUlBXcx1Fz0WE7oPT
#                   81                                      7uzmGiiJyRfuViKKK3lVmR
#                   83                                      1wjzFQodRWrPcQ0AnYnvQ9
# ...

# %%
spotify_songs.loc[1:50,['track_name']]
# Out:
#                                            track_name
# 1                     Memories - Dillon Francis Remix
# 2                     All the Time - Don Diablo Remix
# 3                   Call You Mine - Keanu Silva Remix
# 4             Someone You Loved - Future Humans Remix
# 5   Beautiful People (feat. Khalid) - Jack Wins Remix
# 6                     Never Really Over - R3HAB Remix
# 7            Post Malone (feat. RANI) - GATTÜSO Remix
# 8              Tough Love - Tiësto Remix / Radio Edit
# 9                 If I Can't Have You - Gryffin Remix
# 10  Cross Me (feat. Chance the Rapper & PnB Rock) ...
# 11                              Hate Me - R3HAB Remix
# 12                                         Body On My
# 13     SOS - Laidback Luke Tribute Remix / Radio Edit
# 14  Summer Days (feat. Macklemore & Patrick Stump ...
# 15  South of the Border (feat. Camila Cabello & Ca...
# 16                 All My Friends - Eden Prince Remix
# ...

# %%
spotify_songs.iloc[10:30:2,1:4]
# Out:
#                                            track_name      track_artist  \
# 10  Cross Me (feat. Chance the Rapper & PnB Rock) ...        Ed Sheeran
# 12                                         Body On My       Loud Luxury
# 14  Summer Days (feat. Macklemore & Patrick Stump ...     Martin Garrix
# 16                 All My Friends - Eden Prince Remix       AJ Mitchell
# 18  Dancing With A Stranger (With Normani) - Cheat...         Sam Smith
# 20               Heaven - David Guetta & MORTEN Remix            Avicii
# 22  Don't Leave Me Alone (feat. Anne-Marie) - EDX'...      David Guetta
# 24  Do You Mean (feat. Ty Dolla $ign & bülow) - My...  The Chainsmokers
# 26                  One Thing Right - Firebeatz Remix        Marshmello
# 28                         So Am I - Toby Green Remix           Ava Max
#
#     track_popularity
# 10                58
# 12                67
# 14                63
# 16                60
# 18                69
# 20                70
# ...
